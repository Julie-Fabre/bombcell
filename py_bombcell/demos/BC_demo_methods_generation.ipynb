# %% [markdown]
# # bombcell: Methods Text Generation
#
# This notebook demonstrates how to automatically generate a methods section paragraph, based on the parameters you used to run bombcell.

# %% [markdown]
# ## 1. Setup

# %%
# %load_ext autoreload
# %autoreload 2

import bombcell as bc
from pathlib import Path
# Out:
# ✅ ipywidgets available - interactive GUI ready

# %% [markdown]
# ## 2. Generate methods text from default parameters
#
# If you just want to quickly generate the text with default BombCell parameters:

# %%
# Get default parameters (no data needed)
param = bc.get_default_parameters("/tmp/placeholder")

# Generate and print everything
bc.print_methods_text(param)
# Out:
# ======================================================================
# METHODS
# ======================================================================
# Automated spike sorting quality control was performed using BombCell (Fabre et al., 2023). Each unit was sequentially evaluated and classified as noise, non-somatic, multi-unit activity (MUA), and good single units, based on the quality metrics described below.
#
# Noise and non-somatic quality metrics were derived from each unit's template waveform on its peak channel (the channel with the largest amplitude). Peaks and troughs were identified using a prominence-based peak-finding algorithm, with the minimum prominence threshold set to 0.2 times the waveform's absolute maximum. The main trough was defined as the most prominent trough, and peaks were detected separately on either side of it.
#
# Units were first evaluated for noise-like waveform features. A unit was classified as noise if any of the following criteria were met: the waveform contained more than 2 peaks or more than 1 trough; the peak-to-trough duration (time between the largest peak and largest trough) fell outside 100–1150 µs; the waveform baseline fraction (maximum absolute value in the baseline period preceding the spike, relative to the waveform's absolute peak) exceeded 0.3; or the ratio of the second peak amplitude to the main trough amplitude exceeded 0.8. Additionally, the spatial decay of the waveform was quantified by measuring the absolute peak amplitude on the 10 nearest channels within 33 µm in the x-dimension, as a function of Euclidean distance (in µm) from the peak channel. Amplitudes were normalized to the peak channel, and an exponential fit was applied to obtain the decay slope. Units with a decay slope outside the range 0.01–0.1 were classified as noise.
#
# Non-noise units were then evaluated for non-somatic (e.g., axonal) waveform characteristics (Deligkaris et al., 2016). A unit was classified as non-somatic if any of the following criteria were met: the ratio of the largest peak amplitude (before or after the trough) to the main trough amplitude exceeded 0.8; the ratio of the pre-trough peak amplitude to the post-trough peak amplitude exceeded 3; the ratio of the main trough amplitude to the pre-trough peak amplitude was less than 5; the half-prominence width of the pre-trough peak was less than 4 samples; or the half-prominence width of the main trough was less than 5 samples.
#
# The remaining units were then assessed for single-unit isolation quality, and classified as multi-unit activity (MUA) if any of the following criteria were met. The fraction of refractory period violations was estimated using the method of Hill et al. (2011), with a refractory period of 2.0 ms and a censored period of 0.1 ms; units exceeding 10% violations were classified as MUA. The percentage of missing spikes was estimated by fitting a Gaussian to each unit's amplitude distribution and computing the fraction falling below the detection threshold; units with more than 20% missing spikes were classified as MUA. Units with fewer than 300 total spikes were classified as MUA. The presence ratio was computed by dividing the recording into 60-second bins and calculating the fraction of bins in which the unit's spike count exceeded 5% of the 90th-percentile bin count (inspired by Siegle et al. (2021)); units with a presence ratio below 0.7 were classified as MUA. The raw waveform amplitude (peak-to-trough voltage in µV) was computed from the mean of 100 randomly sampled raw waveforms after linear de-trending; units with an amplitude below 40 µV were classified as MUA. The signal-to-noise ratio (SNR) was defined as the waveform amplitude divided by the standard deviation of the baseline noise; units with an SNR below 5 were classified as MUA.
#
# All remaining units that passed the above criteria were classified as good single units.
#
# ======================================================================
# REFERENCES
# ======================================================================
#   Fabre, J.M.J., van Beest, E.H., Peters, A.J., Carandini, M., & Harris, K.D. (2023). Bombcell: automated curation and cell classification of spike-sorted electrophysiology data. Zenodo. https://doi.org/10.5281/zenodo.8172821
#   Deligkaris, K., Bullmann, T., & Frey, U. (2016). Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology. Frontiers in Neuroscience, 10, 421. https://doi.org/10.3389/fnins.2016.00421
#   Hill, D.N., Mehta, S.B., & Kleinfeld, D. (2011). Quality metrics to accompany spike sorting of extracellular signals. Journal of Neuroscience, 31(24), 8699-8705.
#   Siegle, J.H., Jia, X., Durand, S., et al. (2021). Survey of spiking in the mouse visual system reveals functional hierarchy. Nature, 592, 86-92. https://doi.org/10.1038/s41586-020-03171-x
#
# ======================================================================
# BIBTEX
# ======================================================================
# @misc{fabre2023bombcell,
#   author = {Fabre, Julie M. J. and van Beest, Enny H. and Peters, Andrew J. and Carandini, Matteo and Harris, Kenneth D.},
#   title = {Bombcell: automated curation and cell classification of spike-sorted electrophysiology data},
#   year = {2023},
#   publisher = {Zenodo},
#   doi = {10.5281/zenodo.8172821},
#   url = {https://doi.org/10.5281/zenodo.8172821}
# }
#
# @article{deligkaris2016extracellularly,
#   author = {Deligkaris, Kosmas and Bullmann, Torsten and Frey, Urs},
#   title = {Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology},
#   journal = {Frontiers in Neuroscience},
#   volume = {10},
#   pages = {421},
#   year = {2016},
#   doi = {10.3389/fnins.2016.00421}
# }
#
# @article{hill2011quality,
#   author = {Hill, Daniel N. and Mehta, Samar B. and Kleinfeld, David},
#   title = {Quality metrics to accompany spike sorting of extracellular signals},
#   journal = {Journal of Neuroscience},
#   volume = {31},
#   number = {24},
#   pages = {8699--8705},
#   year = {2011}
# }
#
# @article{siegle2021survey,
#   author = {Siegle, Joshua H. and Jia, Xiaoxuan and Durand, S{\'e}verine and others},
#   title = {Survey of spiking in the mouse visual system reveals functional hierarchy},
#   journal = {Nature},
#   volume = {592},
#   pages = {86--92},
#   year = {2021},
#   doi = {10.1038/s41586-020-03171-x}
# }

# %% [markdown]
# ## 3. Generate from your actual analysis parameters
#
# If you've already run BombCell on your data, you can load your saved parameters and generate from those:

# %%
# Option A: Load saved parameters from a previous BombCell run
# save_path = Path("/path/to/your/kilosort_dir/bombcell")
# param, quality_metrics, _ = bc.load_bc_results(save_path)

# Option B: Use parameters you've configured in this session
ks_dir = "/tmp/placeholder"  # Replace with your kilosort directory
param = bc.get_default_parameters(ks_dir, kilosort_version=4)

# Customize parameters as you would for your analysis
param["tauR_valuesMin"] = 0.5 / 1000
param["tauR_valuesMax"] = 5 / 1000
param["tauR_valuesStep"] = 0.5 / 1000
param["computeDrift"] = True
param["computeDistanceMetrics"] = False
param["computeTimeChunks"] = True
param["maxRPVviolations"] = 0.1
param["minAmplitude"] = 50

# %%
# Generate with inline citations (default)
bc.print_methods_text(param)
# Out:
# ======================================================================
# METHODS
# ======================================================================
# Automated spike sorting quality control was performed using BombCell (Fabre et al., 2023). Each unit was sequentially evaluated and classified as noise, non-somatic, multi-unit activity (MUA), and good single units, based on the quality metrics described below.
#
# Noise and non-somatic quality metrics were derived from each unit's template waveform on its peak channel (the channel with the largest amplitude). Peaks and troughs were identified using a prominence-based peak-finding algorithm, with the minimum prominence threshold set to 0.2 times the waveform's absolute maximum. The main trough was defined as the most prominent trough, and peaks were detected separately on either side of it.
#
# Units were first evaluated for noise-like waveform features. A unit was classified as noise if any of the following criteria were met: the waveform contained more than 2 peaks or more than 1 trough; the peak-to-trough duration (time between the largest peak and largest trough) fell outside 100–1150 µs; the waveform baseline fraction (maximum absolute value in the baseline period preceding the spike, relative to the waveform's absolute peak) exceeded 0.3; or the ratio of the second peak amplitude to the main trough amplitude exceeded 0.8. Additionally, the spatial decay of the waveform was quantified by measuring the absolute peak amplitude on the 10 nearest channels within 33 µm in the x-dimension, as a function of Euclidean distance (in µm) from the peak channel. Amplitudes were normalized to the peak channel, and an exponential fit was applied to obtain the decay slope. Units with a decay slope outside the range 0.01–0.1 were classified as noise.
#
# Non-noise units were then evaluated for non-somatic (e.g., axonal) waveform characteristics (Deligkaris et al., 2016). A unit was classified as non-somatic if any of the following criteria were met: the ratio of the largest peak amplitude (before or after the trough) to the main trough amplitude exceeded 0.8; the ratio of the pre-trough peak amplitude to the post-trough peak amplitude exceeded 3; the ratio of the main trough amplitude to the pre-trough peak amplitude was less than 5; the half-prominence width of the pre-trough peak was less than 4 samples; or the half-prominence width of the main trough was less than 5 samples.
#
# The remaining units were then assessed for single-unit isolation quality, and classified as multi-unit activity (MUA) if any of the following criteria were met. The fraction of refractory period violations was estimated using the method of Hill et al. (2011), testing refractory period values from 0.5 to 5.0 ms in steps of 0.5 ms (with a censored period of 0.1 ms), and selecting the optimal value per unit; units exceeding 10% violations were classified as MUA. The percentage of missing spikes was estimated by fitting a Gaussian to each unit's amplitude distribution and computing the fraction falling below the detection threshold; units with more than 20% missing spikes were classified as MUA. Both the refractory period violation rate and the percentage of missing spikes were additionally computed in 360-second time chunks to identify the most stable recording period for each unit. Units with fewer than 300 total spikes were classified as MUA. The presence ratio was computed by dividing the recording into 60-second bins and calculating the fraction of bins in which the unit's spike count exceeded 5% of the 90th-percentile bin count (inspired by Siegle et al. (2021)); units with a presence ratio below 0.7 were classified as MUA. The raw waveform amplitude (peak-to-trough voltage in µV) was computed from the mean of 100 randomly sampled raw waveforms after linear de-trending; units with an amplitude below 50 µV were classified as MUA. The signal-to-noise ratio (SNR) was defined as the waveform amplitude divided by the standard deviation of the baseline noise; units with an SNR below 5 were classified as MUA. Electrode drift was estimated by computing, in 60-second bins, the spike depth as a weighted center of mass of the first principal component features across channels. Maximum drift was defined as the difference between the maximum and minimum median spike depth across bins; units with drift exceeding 100 µm were classified as MUA.
#
# All remaining units that passed the above criteria were classified as good single units.
#
# ======================================================================
# REFERENCES
# ======================================================================
#   Fabre, J.M.J., van Beest, E.H., Peters, A.J., Carandini, M., & Harris, K.D. (2023). Bombcell: automated curation and cell classification of spike-sorted electrophysiology data. Zenodo. https://doi.org/10.5281/zenodo.8172821
#   Deligkaris, K., Bullmann, T., & Frey, U. (2016). Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology. Frontiers in Neuroscience, 10, 421. https://doi.org/10.3389/fnins.2016.00421
#   Hill, D.N., Mehta, S.B., & Kleinfeld, D. (2011). Quality metrics to accompany spike sorting of extracellular signals. Journal of Neuroscience, 31(24), 8699-8705.
#   Siegle, J.H., Jia, X., Durand, S., et al. (2021). Survey of spiking in the mouse visual system reveals functional hierarchy. Nature, 592, 86-92. https://doi.org/10.1038/s41586-020-03171-x
#
# ======================================================================
# BIBTEX
# ======================================================================
# @misc{fabre2023bombcell,
#   author = {Fabre, Julie M. J. and van Beest, Enny H. and Peters, Andrew J. and Carandini, Matteo and Harris, Kenneth D.},
#   title = {Bombcell: automated curation and cell classification of spike-sorted electrophysiology data},
#   year = {2023},
#   publisher = {Zenodo},
#   doi = {10.5281/zenodo.8172821},
#   url = {https://doi.org/10.5281/zenodo.8172821}
# }
#
# @article{deligkaris2016extracellularly,
#   author = {Deligkaris, Kosmas and Bullmann, Torsten and Frey, Urs},
#   title = {Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology},
#   journal = {Frontiers in Neuroscience},
#   volume = {10},
#   pages = {421},
#   year = {2016},
#   doi = {10.3389/fnins.2016.00421}
# }
#
# @article{hill2011quality,
#   author = {Hill, Daniel N. and Mehta, Samar B. and Kleinfeld, David},
#   title = {Quality metrics to accompany spike sorting of extracellular signals},
#   journal = {Journal of Neuroscience},
#   volume = {31},
#   number = {24},
#   pages = {8699--8705},
#   year = {2011}
# }
#
# @article{siegle2021survey,
#   author = {Siegle, Joshua H. and Jia, Xiaoxuan and Durand, S{\'e}verine and others},
#   title = {Survey of spiking in the mouse visual system reveals functional hierarchy},
#   journal = {Nature},
#   volume = {592},
#   pages = {86--92},
#   year = {2021},
#   doi = {10.1038/s41586-020-03171-x}
# }

# %% [markdown]
# ## 4. Citation styles
#
# You can choose between inline author-year citations or numbered references:

# %%
# Numbered citation style
bc.print_methods_text(param, citation_style="numbered")
# Out:
# ======================================================================
# METHODS
# ======================================================================
# Automated spike sorting quality control was performed using BombCell [1]. Each unit was sequentially evaluated and classified as noise, non-somatic, multi-unit activity (MUA), and good single units, based on the quality metrics described below.
#
# Noise and non-somatic quality metrics were derived from each unit's template waveform on its peak channel (the channel with the largest amplitude). Peaks and troughs were identified using a prominence-based peak-finding algorithm, with the minimum prominence threshold set to 0.2 times the waveform's absolute maximum. The main trough was defined as the most prominent trough, and peaks were detected separately on either side of it.
#
# Units were first evaluated for noise-like waveform features. A unit was classified as noise if any of the following criteria were met: the waveform contained more than 2 peaks or more than 1 trough; the peak-to-trough duration (time between the largest peak and largest trough) fell outside 100–1150 µs; the waveform baseline fraction (maximum absolute value in the baseline period preceding the spike, relative to the waveform's absolute peak) exceeded 0.3; or the ratio of the second peak amplitude to the main trough amplitude exceeded 0.8. Additionally, the spatial decay of the waveform was quantified by measuring the absolute peak amplitude on the 10 nearest channels within 33 µm in the x-dimension, as a function of Euclidean distance (in µm) from the peak channel. Amplitudes were normalized to the peak channel, and an exponential fit was applied to obtain the decay slope. Units with a decay slope outside the range 0.01–0.1 were classified as noise.
#
# Non-noise units were then evaluated for non-somatic (e.g., axonal) waveform characteristics [2]. A unit was classified as non-somatic if any of the following criteria were met: the ratio of the largest peak amplitude (before or after the trough) to the main trough amplitude exceeded 0.8; the ratio of the pre-trough peak amplitude to the post-trough peak amplitude exceeded 3; the ratio of the main trough amplitude to the pre-trough peak amplitude was less than 5; the half-prominence width of the pre-trough peak was less than 4 samples; or the half-prominence width of the main trough was less than 5 samples.
#
# The remaining units were then assessed for single-unit isolation quality, and classified as multi-unit activity (MUA) if any of the following criteria were met. The fraction of refractory period violations was estimated using the method of Hill et al. [3], testing refractory period values from 0.5 to 5.0 ms in steps of 0.5 ms (with a censored period of 0.1 ms), and selecting the optimal value per unit; units exceeding 10% violations were classified as MUA. The percentage of missing spikes was estimated by fitting a Gaussian to each unit's amplitude distribution and computing the fraction falling below the detection threshold; units with more than 20% missing spikes were classified as MUA. Both the refractory period violation rate and the percentage of missing spikes were additionally computed in 360-second time chunks to identify the most stable recording period for each unit. Units with fewer than 300 total spikes were classified as MUA. The presence ratio was computed by dividing the recording into 60-second bins and calculating the fraction of bins in which the unit's spike count exceeded 5% of the 90th-percentile bin count (inspired by Siegle et al. [4]); units with a presence ratio below 0.7 were classified as MUA. The raw waveform amplitude (peak-to-trough voltage in µV) was computed from the mean of 100 randomly sampled raw waveforms after linear de-trending; units with an amplitude below 50 µV were classified as MUA. The signal-to-noise ratio (SNR) was defined as the waveform amplitude divided by the standard deviation of the baseline noise; units with an SNR below 5 were classified as MUA. Electrode drift was estimated by computing, in 60-second bins, the spike depth as a weighted center of mass of the first principal component features across channels. Maximum drift was defined as the difference between the maximum and minimum median spike depth across bins; units with drift exceeding 100 µm were classified as MUA.
#
# All remaining units that passed the above criteria were classified as good single units.
#
# ======================================================================
# REFERENCES
# ======================================================================
#   [1] Fabre, J.M.J., van Beest, E.H., Peters, A.J., Carandini, M., & Harris, K.D. (2023). Bombcell: automated curation and cell classification of spike-sorted electrophysiology data. Zenodo. https://doi.org/10.5281/zenodo.8172821
#   [2] Deligkaris, K., Bullmann, T., & Frey, U. (2016). Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology. Frontiers in Neuroscience, 10, 421. https://doi.org/10.3389/fnins.2016.00421
#   [3] Hill, D.N., Mehta, S.B., & Kleinfeld, D. (2011). Quality metrics to accompany spike sorting of extracellular signals. Journal of Neuroscience, 31(24), 8699-8705.
#   [4] Siegle, J.H., Jia, X., Durand, S., et al. (2021). Survey of spiking in the mouse visual system reveals functional hierarchy. Nature, 592, 86-92. https://doi.org/10.1038/s41586-020-03171-x
#
# ======================================================================
# BIBTEX
# ======================================================================
# @misc{fabre2023bombcell,
#   author = {Fabre, Julie M. J. and van Beest, Enny H. and Peters, Andrew J. and Carandini, Matteo and Harris, Kenneth D.},
#   title = {Bombcell: automated curation and cell classification of spike-sorted electrophysiology data},
#   year = {2023},
#   publisher = {Zenodo},
#   doi = {10.5281/zenodo.8172821},
#   url = {https://doi.org/10.5281/zenodo.8172821}
# }
#
# @article{deligkaris2016extracellularly,
#   author = {Deligkaris, Kosmas and Bullmann, Torsten and Frey, Urs},
#   title = {Extracellularly recorded somatic and neuritic signal shapes and classification algorithms for high-density microelectrode array electrophysiology},
#   journal = {Frontiers in Neuroscience},
#   volume = {10},
#   pages = {421},
#   year = {2016},
#   doi = {10.3389/fnins.2016.00421}
# }
#
# @article{hill2011quality,
#   author = {Hill, Daniel N. and Mehta, Samar B. and Kleinfeld, David},
#   title = {Quality metrics to accompany spike sorting of extracellular signals},
#   journal = {Journal of Neuroscience},
#   volume = {31},
#   number = {24},
#   pages = {8699--8705},
#   year = {2011}
# }
#
# @article{siegle2021survey,
#   author = {Siegle, Joshua H. and Jia, Xiaoxuan and Durand, S{\'e}verine and others},
#   title = {Survey of spiking in the mouse visual system reveals functional hierarchy},
#   journal = {Nature},
#   volume = {592},
#   pages = {86--92},
#   year = {2021},
#   doi = {10.1038/s41586-020-03171-x}
# }

# %% [markdown]
# ## 5. Save to files
#
# `save_methods_text` writes both a `.txt` file (methods + references) and a `.bib` file (BibTeX) side by side.

# %%
# Save methods text (.txt) and BibTeX (.bib) to disk
# save_dir = Path("/path/to/your/output")
# bc.save_methods_text(param, save_dir / "bombcell_methods.txt")
# # This creates:
# #   bombcell_methods.txt  - methods paragraph + formatted references
# #   bombcell_methods.bib  - BibTeX entries for your bibliography

# If you also have quality_metrics loaded, pass them in for a unit count summary:
# bc.save_methods_text(param, save_dir / "bombcell_methods.txt", quality_metrics=quality_metrics)
